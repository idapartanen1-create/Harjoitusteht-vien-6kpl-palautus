# %%
creator="Ida"
number1=12
number2=8
multiplication=("*")
addition=("+")
divison=("/")
substraction=("-")

# %%
print(creator)
print("Printer app")
print("This app is made by:" + creator)

# print (num1)
# print("The value of number1 is "+ number1) 
print("the value of  number2 is ",number2)

sum1= (number1 *  number2)
print(number1, multiplication,number2, "is =", sum1)


sum2=(number1 + number2)
print(number1, addition ,number2, "is =", sum2)


sum3=(number1 / number2)
print(number1, divison ,number2, "is =", sum3)

sum4=(number1 - number2)
print(number1, substraction ,number2, "is =", sum4)
# Out:
# Ida
# Printer app
# This app is made by:Ida
# the value of  number2 is  8
# 12 * 8 is = 96
# 12 + 8 is = 20
# 12 / 8 is = 1.5
# 12 - 8 is = 4
