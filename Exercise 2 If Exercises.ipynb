# %%
#1 tehtävään tarkoiteut muuttujat
# number1=9
# number2=8



#Ensimmäiset 2 tehtävään tarkoitetut muuttujat
number1=7
number2=6
number3=7



#3 tehtävään tarkoitetut muuttujat
#a
# name1="Elsa"
# name2="Elsa"
# name3="Diana"
#b ja c
# name1="Elsa"
# name2="Diana"
# name3="Elsa"
#c
name1="Elsa"
name2="Diana"
name3="Elsa"

# %%
# 1

#a
# if   number1 == number2:
#     print("number1 is equal to number2")
# else:
#     print("number1 is not equal to number2")


#b
# if   number1 > number2:
#     print("number1 is greater to number2")
# else:
#     print("number1 is not greater to number2")


#c
# if   number1 >= number2:
#     print("number1 is greater to number2")
# else:
#     print("number1 is not greater to number2")


#d
# if   number1 == number2:
#     print("number1 is equal to number2")
# else:
#     print("number1 is not equal to number2")
# Out:
# number1 is not equal to number2
# number1 is greater to number2
# number1 is greater to number2
# number1 is not equal to number2

# %%
# 2 


#a
if (number1 == number2 & number2 == number3):
    print ("Numbers are equal")
else:
    print ("Not any numbers are equal")


#b
if (number1 == number2 | number2 == number3):
    print ("Numbers are equal")
else:
    print ("Not any numbers are equal")


#c
if (number1 > number2 and number1 > number3):
    print ("Number1 is the greatest of all three")
else:
    print ("Number1 is not the biggest number")

#d
if (number1 > number2):
    print("Number1 is greater than number2")
elif (number2 > number3):
    print("number2 is greater than number3")
else: 
    print("Neither condition was true")


#e
if (number1 == number2):
    print("Number1 is greater than number2")
elif (number1 == number3):
    print("number1 is greater than number3")
else: 
    print("Neither condition was true")
# Out:
# Not any numbers are equal
# Not any numbers are equal
# Number1 is not the biggest number
# Number1 is greater than number2
# number1 is greater than number3

# %%
#3

#a
if   name1 == name2:
    print(name1 + " is equal to " + name2)
else:
    print("names are not equal")


#b
if   name1 == name2:
    print(name1 + " is equal to " + name2)
else:
    print("names are not equal")

#c
if (name1 == name2):
    print("name1 is equal to name2")
elif (number1 == number3):
    print("name1 is equal to Name3")
else: 
    print("No names are equal")
# Out:
# names are not equal
# names are not equal
# name1 is equal to Name3
