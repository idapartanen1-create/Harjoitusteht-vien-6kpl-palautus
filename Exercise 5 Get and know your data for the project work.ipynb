# %%
import pandas as pd
df = pd.read_csv('spotify_data clean.csv', encoding='utf-8')

# %%
df.head(10)
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
# 5  4ccpCcZYseq8VrPMK1EDs0                                            BLEED
# 6  3QoQ3HqXTAjgEl9LbNMbYp                             Te Procuro na Cidade
# 7  1YEZbdT417SfolPQzaoHs2                                      come closer
# 8  4pZ949nFW5SurwzE0TSe7I                                 Cupido Vagabundo
# 9  0L0LgwFZ7UtBnRNQvSBty6                                        LET’S GO!
#
#    track_number  track_popularity  explicit     artist_name  \
# 0             4                 0      True           Diplo
# ...

# %%
df.shape[0]
# Out:
# 8582

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
df.shape
# Out:
# (8582, 15)

# %%
df.shape[1]
# Out:
# 15

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'explicit', 'artist_name', 'artist_popularity', 'artist_followers',
#        'artist_genres', 'album_id', 'album_name', 'album_release_date',
#        'album_total_tracks', 'album_type', 'track_duration_min'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8582, step=1)

# %%
df.values
# Out:
# array([['3EJS5LyekDim1Tf5rBFmZl', 'Trippy Mane (ft. Project Pat)', 4,
#         ..., 9, 'album', 1.55],
#        ['1oQW6G2ZiwMuHqlPpP27DB', 'OMG!', 1, ..., 1, 'single', 3.07],
#        ['7mdkjzoIYlf1rx9EtBpGmU', 'Hard 2 Find', 1, ..., 1, 'single',
#         2.55],
#        ...,
#        ['0Vy7wsXNFrbNc6UTWoScnM', 'Over the Rainbow', 5, ..., 9,
#         'compilation', 2.28],
#        ['760clbeDBWmBsBLbszWuNZ', "I'm A Man", 2, ..., 12, 'album', 2.74],
#        ['61GEP8lryEfcuEgBMbRmNi', 'Alone And Forsaken', 11, ..., 12,
#         'album', 2.02]], shape=(8582, 15), dtype=object)

# %%
column_data_types = df.dtypes
print(column_data_types)
# Out:
# track_id               object
# track_name             object
# track_number            int64
# track_popularity        int64
# explicit                 bool
# artist_name            object
# artist_popularity       int64
# artist_followers        int64
# artist_genres          object
# album_id               object
# album_name             object
# album_release_date     object
# album_total_tracks      int64
# album_type             object
# track_duration_min    float64
# dtype: object

# %%
column_data_type = df['track_name'].dtype
print(column_data_type)
# Out:
# object

# %%
df.sort_values("artist_name")
# Out:
#                     track_id                   track_name  track_number  \
# 5223  4irYeuAi87yyGHcI4h9s0x                        Paris             1
# 4002  2XSrt1dcuOXPgl3B4bxmBz                   Carrollton            12
# 2055  5MZTbo1le4oNXF1EedvzKC  My Name Is Skyler White, Yo             1
# 2154  7v2sHmJnOKnOSqBijE3KdG         One Dance - 8D Audio             1
# 7937  62bOmKYxYg7dhrC6gH9vFn                  Bye Bye Bye             1
# ...                      ...                          ...           ...
# 2392  5QcAVWXiPZKwPKROCadd7O                       ミリス神聖国            10
# 1534  2hGjDO3JSEh4haZlRTFrPd                        無詠唱魔術             1
# 1807  2NbsBSshscKIPRG3kwBbfo          Never Felt So Alone             1
# 6517  3QhfFRPkhPCR1RMJWV1gde                        Radio             8
# 6679  5EhZC8GFOVXrpiUW22jncE               Urban Twilight             4
#
#       track_popularity  explicit  artist_name  artist_popularity  \
# ...

# %%
df.sort_values("artist_name", ascending=False)
# Out:
#                     track_id           track_name  track_number  \
# 1534  2hGjDO3JSEh4haZlRTFrPd                無詠唱魔術             1
# 2392  5QcAVWXiPZKwPKROCadd7O               ミリス神聖国            10
# 5170  7ELb8yTy4XB6YudgKCApmY       the first town             2
# 5125  4RebD589eKGktAiWDow2wr        シシリエンヌ Op. 78             9
# 4752  3bIDChBaVZvtnU7cOW6k22                   天泣            12
# ...                      ...                  ...           ...
# 4002  2XSrt1dcuOXPgl3B4bxmBz           Carrollton            12
# 5223  4irYeuAi87yyGHcI4h9s0x                Paris             1
# 1807  2NbsBSshscKIPRG3kwBbfo  Never Felt So Alone             1
# 6517  3QhfFRPkhPCR1RMJWV1gde                Radio             8
# 6679  5EhZC8GFOVXrpiUW22jncE       Urban Twilight             4
#
#       track_popularity  explicit  artist_name  artist_popularity  \
# 1534                24     False         藤澤慶昌                 40
# ...

# %%
df.sort_values(["artist_name", "album_name"])

df.sort_values(["artist_name", "album_name"], ascending=[True, False])
# Out:
#                     track_id                   track_name  track_number  \
# 5223  4irYeuAi87yyGHcI4h9s0x                        Paris             1
# 4002  2XSrt1dcuOXPgl3B4bxmBz                   Carrollton            12
# 2055  5MZTbo1le4oNXF1EedvzKC  My Name Is Skyler White, Yo             1
# 2154  7v2sHmJnOKnOSqBijE3KdG         One Dance - 8D Audio             1
# 7937  62bOmKYxYg7dhrC6gH9vFn                  Bye Bye Bye             1
# ...                      ...                          ...           ...
# 1534  2hGjDO3JSEh4haZlRTFrPd                        無詠唱魔術             1
# 2392  5QcAVWXiPZKwPKROCadd7O                       ミリス神聖国            10
# 1807  2NbsBSshscKIPRG3kwBbfo          Never Felt So Alone             1
# 6679  5EhZC8GFOVXrpiUW22jncE               Urban Twilight             4
# 6517  3QhfFRPkhPCR1RMJWV1gde                        Radio             8
#
#       track_popularity  explicit  artist_name  artist_popularity  \
# ...

# %%
subset_chipo = df["artist_name"]
print(subset_chipo)


subset_chipo1 = df[["artist_name", "album_name", "artist_genres"]]
print(subset_chipo1)
# Out:
# 0               Diplo
# 1            Yelawolf
# 2           Riff Raff
# 3               Diplo
# 4             Rumelis
#             ...
# 8577    Marty Robbins
# 8578    Marty Robbins
# 8579      The Mystics
# 8580       Bo Diddley
# 8581    Hank Williams
# Name: artist_name, Length: 8582, dtype: object
#         artist_name                            album_name  \
# 0             Diplo                    d00mscrvll, Vol. 1
# 1          Yelawolf                                  OMG!
# 2         Riff Raff                           Hard 2 Find
# 3             Diplo                    d00mscrvll, Vol. 1
# 4           Rumelis   come closer / ride me like a harley
# ...             ...                                   ...
# 8577  Marty Robbins    Gunfighter Ballads And Trail Songs
# 8578  Marty Robbins    Gunfighter Ballads And Trail Songs
# 8579    The Mystics                Presenting The Mystics
# 8580     Bo Diddley                            Bo Diddley
# ...

# %%
subset_df = df[df['artist_followers'] > 1000]
print(subset_df)


subset_df = df[df['artist_genres'] == "classic blues"]
print(subset_df)

subset_df1 = df['artist_followers'] > 1000
subset_df2 = df['artist_genres'] == "classic blues"
subset_df3 = df[subset_df1 & subset_df2]
subset_df3.head()
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
print(df['artist_name'].dtype)
# Out:
# object

# %%
df['total'] = df['track_number'] * df['artist_popularity']

df.head(20)
# Out:
#                   track_id                                       track_name  \
# 0   3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1   1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2   7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3   67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4   15xptTfRBrjsppW0INUZjf                            ride me like a harley
# 5   4ccpCcZYseq8VrPMK1EDs0                                            BLEED
# 6   3QoQ3HqXTAjgEl9LbNMbYp                             Te Procuro na Cidade
# 7   1YEZbdT417SfolPQzaoHs2                                      come closer
# 8   4pZ949nFW5SurwzE0TSe7I                                 Cupido Vagabundo
# 9   0L0LgwFZ7UtBnRNQvSBty6                                        LET’S GO!
# 10  5mfAZwEr4jAVDnSY0HHuyH                                            Stray
# ...

# %%
def categorize_price(track_number):
    if track_number < 5:
        return 'Low'
    elif track_number < 10:
        return 'mMdium'
    else:
        return 'High'

df['track_popularity'] = df['track_name'].apply(categorize_price)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 9
#       6     else:
#       7         return 'false'
# ----> 9 df['track_popularity'] = df['track_name'].apply(categorize_price)
#      10 df.head()
#
# File c:\Users\idapa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
# ...
