# %%
import pandas as pd

# %%
df = {"Artist_popularity": [77, 64, 48], 'track_id': ['3EJS5LyekDim1Tf5rBFmZl', '1oQW6G2ZiwMuHqlPpP27DB', '7mdkjzoIYlf1rx9EtBpGmU'], "album_total_tracks": [9, 1, 1]}
df2=pd.DataFrame(df)

# %%
df3= {"artist_followers	": [2812821	, 2363438, 193302], 'explicit': ['true', 'true', 'true'], 'track_name': ["Trippy Mane(ft. Project Pat)"	," OMG!"	, "Hard 2 Find"]}
df4=pd.DataFrame(df3)

# %%
combined_df = pd.concat([df2, df4,], ignore_index=True)
print(combined_df)
# Out:
#    Artist_popularity                track_id  album_total_tracks  \
# 0               77.0  3EJS5LyekDim1Tf5rBFmZl                 9.0
# 1               64.0  1oQW6G2ZiwMuHqlPpP27DB                 1.0
# 2               48.0  7mdkjzoIYlf1rx9EtBpGmU                 1.0
# 3                NaN                     NaN                 NaN
# 4                NaN                     NaN                 NaN
# 5                NaN                     NaN                 NaN
#
#    artist_followers\t explicit                    track_name
# 0                 NaN      NaN                           NaN
# 1                 NaN      NaN                           NaN
# 2                 NaN      NaN                           NaN
# 3           2812821.0     true  Trippy Mane(ft. Project Pat)
# 4           2363438.0     true                          OMG!
# 5            193302.0     true                   Hard 2 Find

# %%
data = {'track_duration_min': [1.55, 3.07, 2.55],'album_id': ['5QRFnGnBeMePBKF2x7z5z','Piz4Summmnv0xTjrCLdjzcGg2za', '3E3zEAL8gUVWaLYB9L7gbp'],'track_number': [4, 1, 1]}
data_df = pd.DataFrame(data)


data2 = {'track_number': [4, 1, 1],'artist_followers': [2812821, 2363438, 193302]}
data3 = pd.DataFrame(data2)

# %%
merged_df = pd.merge(data_df, data3, on='track_number')
print(merged_df)
# Out:
#    track_duration_min                     album_id  track_number  \
# 0                1.55        5QRFnGnBeMePBKF2x7z5z             4
# 1                3.07  Piz4Summmnv0xTjrCLdjzcGg2za             1
# 2                3.07  Piz4Summmnv0xTjrCLdjzcGg2za             1
# 3                2.55       3E3zEAL8gUVWaLYB9L7gbp             1
# 4                2.55       3E3zEAL8gUVWaLYB9L7gbp             1
#
#    artist_followers
# 0           2812821
# 1           2363438
# 2            193302
# 3           2363438
# 4            193302
