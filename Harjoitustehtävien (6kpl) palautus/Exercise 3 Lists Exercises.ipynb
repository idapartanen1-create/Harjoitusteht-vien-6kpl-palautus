# %%
#Harjoitus 1, kohta 1
Furniture1="table"
furniture2="chair"
furniture3="sofa"
furniture4="Shelf"

# %%
#Harjoitus 1, kohta 2
print(Furniture1, furniture2, furniture3)

#Harjoitus 1, kohta 3
# Out:
# table chair sofa
