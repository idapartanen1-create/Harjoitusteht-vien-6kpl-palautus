# %%
CorrectName="Ida"

# %%
while True:
    guess =input("Guess a name: ")
    if guess == CorrectName:
        print("Congratulation!")
        break
    else:
        print("Wrong name, try again")
# Out:
# Congratulation!
